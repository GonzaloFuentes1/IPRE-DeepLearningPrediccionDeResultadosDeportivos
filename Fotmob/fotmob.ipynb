# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import json
import os
import sys
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from random import choice
from time import time

# %%
df = pd.read_csv("datos_fotmob_completo.csv")
# Cambiamos los nombres de algunas variables, dropeamos los valores vacios y ordenamos por fecha
# La fecha va de la más antigua a la más nueva
df.rename(columns={'homeTeam_score': 'score_home',"awayTeam_score":"score_away"}, inplace=True)
df.rename(columns={'homeTeam': 'team_home',"awayTeam":"team_away"}, inplace=True)
df = df.sort_values(by="date",ignore_index=True)
df = df.drop(["discipline_away","discipline_home","duels_home","duels_away","defense_home","defense_away","shots_home","shots_away"], axis =1)
#Este dropeo es por mientras
df = df.drop(["accurate_passes_home","accurate_passes_away","long_balls_accurate_home","long_balls_accurate_away","accurate_crosses_home","accurate_crosses_away",
              "tackles_succeeded_home","tackles_succeeded_away","ground_duels_won_home","ground_duels_won_away","aerials_won_home","aerials_won_away",
              "dribbles_succeeded_home","dribbles_succeeded_away"], axis =1)
# Este dropeo hay que conversarlo
df.head()
# Out:
#         id        date      leagueName          team_home        team_away  \
# 0  1474723  2014-01-01  Premier League       Swansea City  Manchester City
# 1  1475995  2014-01-01      League Two  Scunthorpe United         Rochdale
# 2  1474676  2014-01-01  Premier League            Arsenal     Cardiff City
# 3  1474680  2014-01-01  Premier League     Crystal Palace     Norwich City
# 4  1474689  2014-01-01  Premier League             Fulham  West Ham United
#
#    score_home  score_away  homeIdTeam  awayIdTeam  parentLeagueId  ...  \
# 0           2           3       10003        8456            47.0  ...
# 1           3           0        8412        8493           109.0  ...
# 2           2           0        9825        8344            47.0  ...
# 3           1           1        9826        9850            47.0  ...
# 4           2           1        9879        8654            47.0  ...
#
#    expected_goals_home  expected_goals_away  expected_goals_open_play_home  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3                  NaN                  NaN                            NaN
# 4                  NaN                  NaN                            NaN
#
#    expected_goals_open_play_away  expected_goals_set_play_home  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    expected_goals_set_play_away  expected_goals_non_penalty_home  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    expected_goals_non_penalty_away  expected_goals_on_target_home  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    expected_goals_on_target_away
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 71 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475283 entries, 0 to 475282
# Data columns (total 71 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id                               475283 non-null  int64
#  1   date                             475283 non-null  object
#  2   leagueName                       475283 non-null  object
#  3   team_home                        475283 non-null  object
#  4   team_away                        475283 non-null  object
#  5   score_home                       475283 non-null  int64
#  6   score_away                       475283 non-null  int64
#  7   homeIdTeam                       475283 non-null  int64
#  8   awayIdTeam                       475283 non-null  int64
#  9   parentLeagueId                   473281 non-null  float64
#  10  leagueId                         473281 non-null  float64
#  11  BallPossesion_home               137910 non-null  float64
#  12  BallPossesion_away               137910 non-null  float64
#  13  ShotsOnTarget_home               137910 non-null  float64
#  14  ShotsOnTarget_away               137910 non-null  float64
#  15  ShotsOffTarget_home              137910 non-null  float64
#  16  ShotsOffTarget_away              137910 non-null  float64
#  17  fouls_home                       137910 non-null  float64
#  18  fouls_away                       137910 non-null  float64
#  19  Offsides_home                    137910 non-null  float64
#  20  Offsides_away                    137910 non-null  float64
#  21  corners_home                     137910 non-null  float64
#  22  corners_away                     137910 non-null  float64
#  23  total_shots_home                 92719 non-null   float64
#  24  total_shots_away                 92719 non-null   float64
#  25  big_chance_home                  92719 non-null   float64
#  26  big_chance_away                  92719 non-null   float64
#  27  big_chance_missed_title_home     92719 non-null   float64
#  28  big_chance_missed_title_away     92719 non-null   float64
#  29  blocked_shots_home               92719 non-null   float64
#  30  blocked_shots_away               92719 non-null   float64
#  31  shots_woodwork_home              92719 non-null   float64
#  32  shots_woodwork_away              92719 non-null   float64
#  33  shots_inside_box_home            92719 non-null   float64
#  34  shots_inside_box_away            92719 non-null   float64
#  35  shots_outside_box_home           92719 non-null   float64
#  36  shots_outside_box_away           92719 non-null   float64
#  37  passes_home                      92719 non-null   float64
#  38  passes_away                      92719 non-null   float64
#  39  own_half_passes_home             92719 non-null   float64
#  40  own_half_passes_away             92719 non-null   float64
#  41  opposition_half_passes_home      92719 non-null   float64
#  42  opposition_half_passes_away      92719 non-null   float64
#  43  player_throws_home               92719 non-null   float64
#  44  player_throws_away               92719 non-null   float64
#  45  interceptions_home               92719 non-null   float64
#  46  interceptions_away               92719 non-null   float64
#  47  shot_blocks_home                 92719 non-null   float64
#  48  shot_blocks_away                 92719 non-null   float64
#  49  clearances_home                  92719 non-null   float64
#  50  clearances_away                  92719 non-null   float64
#  51  keeper_saves_home                92719 non-null   float64
#  52  keeper_saves_away                92719 non-null   float64
#  53  duel_won_home                    92719 non-null   float64
#  54  duel_won_away                    92719 non-null   float64
#  55  yellow_cards_home                92719 non-null   float64
#  56  yellow_cards_away                92719 non-null   float64
#  57  red_cards_home                   92719 non-null   float64
#  58  red_cards_away                   92719 non-null   float64
#  59  touches_opp_box_home             11592 non-null   float64
#  60  touches_opp_box_away             11590 non-null   float64
#  61  expected_goals_home              28592 non-null   float64
#  62  expected_goals_away              28592 non-null   float64
#  63  expected_goals_open_play_home    28592 non-null   float64
#  64  expected_goals_open_play_away    28592 non-null   float64
#  65  expected_goals_set_play_home     28514 non-null   float64
#  66  expected_goals_set_play_away     28514 non-null   float64
#  67  expected_goals_non_penalty_home  28588 non-null   float64
#  68  expected_goals_non_penalty_away  28588 non-null   float64
#  69  expected_goals_on_target_home    28584 non-null   float64
#  70  expected_goals_on_target_away    28584 non-null   float64
# dtypes: float64(62), int64(5), object(4)
# memory usage: 257.5+ MB

# %%
# Estadisticas simples, ver si jugar en casa afecta
home_win = 0
away_win = 0
draw = 0

total = len(df)
home_win_percentage = sum(df["score_home"] > df["score_away"])/total
away_win_percentage = sum(df["score_home"] < df["score_away"])/total
draw_perentage = sum(df["score_home"] == df["score_away"])/total

# %%
print(home_win_percentage)
print(away_win_percentage)
print(draw_perentage)
# Out:
# 0.4343096639265448
# 0.2995646804114601
# 0.2661256556619951

# %%
def get_features(data, side):
    if side == "home":
        return data[5:59].values
    elif side == "away": 
        original_lista = data.keys()[5:59]
        nueva_lista = [item.replace('home', 'temp').replace('away', 'home').replace('temp', 'away') for item in original_lista]
        return data.get(nueva_lista).values

# Esta funcion esta optimizada para funcionar con JobLib en paralelo
# Puesto que así es mucho más rápido.
def search_features(i, df, last_games):
    # W = home_win, D = draw, L = home_lose
    team_home = df.iloc[i]["team_home"]
    team_away = df.iloc[i]["team_away"]
    home_search = last_games
    away_search = last_games
    # W = win, D = draw, L = lose
    info_home = []
    info_away = []
    info_features_home = []
    info_features_away = []
    # Para hacer la busqueda más eficiente, solo buscamos en los partidos que estos equipos juegan
    df_match1 = df[df["team_home"] == team_home]
    df_match2 = df[df["team_away"] == team_home]
    df_match3 = df[df["team_home"] == team_away]
    df_match4 = df[df["team_away"] == team_away]
    df_match_index = sorted(list(set(df_match1.index) | set(df_match2.index) | set(
        df_match3.index) | set(df_match4.index)), reverse=True)
    # iteramos solo en los 
    for j in df_match_index:
        if away_search == 0 and home_search == 0:
            features_home_games = np.sum(info_features_home, axis=0)/last_games
            features_away_games = np.sum(info_features_away, axis=0)/last_games
            if df.iloc[i]["score_home"] > df.iloc[i]["score_away"]:
                result = "W"
            elif df.iloc[i]["score_home"] == df.iloc[i]["score_away"]:
                result = "D"
            elif df.iloc[i]["score_home"] < df.iloc[i]["score_away"]:
                result = "L"
            return info_home, info_away, result, i,features_home_games,features_away_games
        # Buscamos los partidos anteriores del equipo de CASA
        # Como i es el partido actual y j el que estamos buscando,
        # si  i<j, entonces estamos en un partido del futuro (por lo que queremos lo contrario)
        if home_search > 0 and i-j > 0:
            if team_home == df.iloc[j]["team_home"]:
                info_features_home.append(
                        get_features(df.iloc[j], side="home"))
                home_search -= 1
                # Casa gana
                if df.iloc[j]["score_home"] > df.iloc[j]["score_away"]:
                    info_home.append("W")
                # Casa pierde
                elif df.iloc[j]["score_home"] < df.iloc[j]["score_away"]:
                    info_home.append("L")
                # Casa empata
                elif df.iloc[j]["score_home"] == df.iloc[j]["score_away"]:
                    info_home.append("D")
            elif team_home == df.iloc[j]["team_away"]:
                info_features_home.append(
                    get_features(df.iloc[j], side="away"))
                home_search -= 1
                # Visita gana
                if df.iloc[j]["score_away"] > df.iloc[j]["score_home"]:
                    info_home.append("W")
                # Visita pierde
                elif df.iloc[j]["score_away"] < df.iloc[j]["score_home"]:
                    info_home.append("L")
                # Visita empata
                elif df.iloc[j]["score_away"] == df.iloc[j]["score_home"]:
                    info_home.append("D")

        # Buscamos los partidos anteriores del equipo de VISITA
        if away_search > 0 and i-j > 0:
            if team_away == df.iloc[j]["team_home"]:
                info_features_away.append(
                    get_features(df.iloc[j], side="home"))
                away_search -= 1
                # Casa gana
                if df.iloc[j]["score_home"] > df.iloc[j]["score_away"]:
                    info_away.append("W")
                # Casa pierde
                elif df.iloc[j]["score_home"] < df.iloc[j]["score_away"]:
                    info_away.append("L")
                # Casa empata
                elif df.iloc[j]["score_home"] == df.iloc[j]["score_away"]:
                    info_away.append("D")
            elif team_away == df.iloc[j]["team_away"]:
                info_features_away.append(
                    get_features(df.iloc[j], side="away"))
                away_search -= 1
                # Visita gana
                if df.iloc[j]["score_away"] > df.iloc[j]["score_home"]:
                    info_away.append("W")
                # Visita pierde
                elif df.iloc[j]["score_away"] < df.iloc[j]["score_home"]:
                    info_away.append("L")
                # Visita empata
                elif df.iloc[j]["score_away"] == df.iloc[j]["score_home"]:
                    info_away.append("D")

# %%
# Pruebas de dataframe
df_test = df[df["red_cards_away"].notnull()].reset_index(drop=True)
lista_de_testeo= list(df_test.index)
df_test
# Out:
#             id        date                   leagueName          team_home  \
# 0      1636598  2014-01-26                       FA Cup            Chelsea
# 1      1473211  2014-02-02                   Eredivisie       RKC Waalwijk
# 2      1474970  2014-02-11               Premier League          Hull City
# 3      1627329  2014-02-19     Copa Libertadores Grp. 5  Defensor Sporting
# 4      1473240  2014-02-22                   Eredivisie            Cambuur
# ...        ...         ...                          ...                ...
# 92714  4203029  2024-02-06                   League One          Port Vale
# 92715  4238239  2024-02-07                      3. Liga       Unterhaching
# 92716  4221121  2024-02-14                  Premiership            Rangers
# 92717  4221124  2024-02-14                  Premiership           Aberdeen
# 92718  4343093  2024-02-16  CAF Champions League Grp. D      CR Belouizdad
#
#               team_away  score_home  score_away  homeIdTeam  awayIdTeam  \
# 0            Stoke City           1           0        8455       10194
# 1         PSV Eindhoven           2           0       10219        8640
# 2           Southampton           0           1        8667        8466
# 3              Cusco FC           4           1        7796      305171
# 4      Roda JC Kerkrade           1           0        7788        9803
# ...                 ...         ...         ...         ...         ...
# 92714     Leyton Orient           0           1        9799        8351
# 92715     Hallescher FC           2           0        8486        7761
# 92716       Ross County           3           1        8548        8649
# 92717        Motherwell           3           3        8485        9927
# 92718        Al Ahly SC           0           0      101633      101745
#
#        parentLeagueId  ...  expected_goals_home  expected_goals_away  \
# 0               132.0  ...                  NaN                  NaN
# 1                57.0  ...                  NaN                  NaN
# 2                47.0  ...                  NaN                  NaN
# 3                45.0  ...                  NaN                  NaN
# 4                57.0  ...                  NaN                  NaN
# ...               ...  ...                  ...                  ...
# 92714           108.0  ...                 0.32                 1.69
# 92715           208.0  ...                  NaN                  NaN
# 92716            64.0  ...                 4.91                 0.54
# 92717            64.0  ...                 1.42                 2.56
# 92718           526.0  ...                  NaN                  NaN
#
#        expected_goals_open_play_home  expected_goals_open_play_away  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 92714                           0.26                           1.59
# 92715                            NaN                            NaN
# 92716                           4.34                           0.45
# 92717                           0.73                           1.69
# 92718                            NaN                            NaN
#
#        expected_goals_set_play_home  expected_goals_set_play_away  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 92714                          0.05                          0.10
# 92715                           NaN                           NaN
# 92716                          0.57                          0.09
# 92717                          0.69                          0.08
# 92718                           NaN                           NaN
#
#        expected_goals_non_penalty_home  expected_goals_non_penalty_away  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 92714                             0.32                             1.69
# 92715                              NaN                              NaN
# 92716                             4.91                             0.54
# 92717                             1.42                             1.77
# 92718                              NaN                              NaN
#
#        expected_goals_on_target_home  expected_goals_on_target_away
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 92714                           0.27                           2.46
# 92715                            NaN                            NaN
# 92716                           5.27                           0.84
# 92717                           1.99                           3.61
# 92718                            NaN                            NaN
#
# [92719 rows x 71 columns]

# %%
# Programa lineal
last_games = 15
resultados = []
for i in tqdm(lista_de_testeo):
    info = search_features(i,df_test.head(i+1),last_games)
    resultados.append(info)
# Out:
# 100%|██████████| 92719/92719 [35:17<00:00, 43.78it/s]

# %%
# Programa paralelo (Cuidado que a veces las particiones se quedan sin memoria, error de pickle)

# Last games = Juegos pasados a tener en cuenta
# Num_trabajadores = Trabajadores en paralelo (usar -1 para todos los posibles)
# Se demora un par de minutos
last_games = 15
num_trabajadores = -1
resultados = Parallel(n_jobs=num_trabajadores,verbose=10)(
    delayed(search_features)(i,df_test.head(i+1), last_games) for i in lista_de_testeo)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.18014844135436328s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04012560844421387s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.13201045989990234s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 748 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 916 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 1084 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 1268 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 1452 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 1652 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 1852 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 2068 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0055586420861804s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 2284 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 2390 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 2447 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done 2485 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 2516 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 2549 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 2582 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 2617 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 2652 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 2689 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=-1)]: Done 2726 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 2765 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 2804 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 2845 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 2886 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 2929 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 2972 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 3017 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done 3062 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 3109 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 3156 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 3205 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 3254 tasks      | elapsed:   27.4s
# [Parallel(n_jobs
AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\cloudpickle\cloudpickle_fast.py", line 632, in dump
#     return Pickler.dump(self, obj)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_memmapping_reducer.py", line 446, in __call__
#     for dumped_filename in dump(a, filename):
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\numpy_pickle.py", line 553, in dump
#     NumpyPickler(f, protocol=protocol).dump(value)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\pickle.py", line 487, in dump
#     self.save(obj)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\numpy_pickle.py", line 352, in save
#     wrapper.write_array(obj, self)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\numpy_pickle.py", line 134, in write_array
#     pickler.file_handle.write(chunk.tobytes('C'))
# OSError: [Errno 28] No space left on device
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[10], line 6
#       4 last_games = 15
#       5 num_trabajadores = -1
# ----> 6 resultados = Parallel(n_jobs=num_trabajadores,verbose=10)(
#       7     delayed(search_features)(i,df_test.head(i+1), last_games) for i in lista_de_testeo)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# PicklingError: Could not pickle the task to send it to the workers.

# %%
# X = Input Features
# Y = Outputs
# Index = Para identificar donde están en el dataframe original

# Los valores de X son tal que :
# [home_wins, home_draws, home_lose,
# away_wins, away_draws, away_lose,
# *[home_match1_win/lose/draw],*[home_match2_win/lose/draw],...*[home_matchN_win/lose/draw],
# *[away_match1_win/lose/draw],*[away_match2_win/lose/draw],...*[away_matchN_win/lose/draw]]
# Donde 
# *[XXX_match1_win/lose/draw] = *[1,0,0] = win
# *[XXX_match1_win/lose/draw] = *[0,1,0] = draw
# *[XXX_match1_win/lose/draw] = *[0,0,1] = lose
X = []
Y = []
index = []
for i in range(len(resultados)):
    if resultados[i] != None:
        index.append(resultados[i][3])
        
        streak_home = resultados[i][0]
        streak_away = resultados[i][1]
        result = resultados[i][2]

        # Suma de resultados

        home_wins = streak_home.count("W")
        home_draws = streak_home.count("D")
        home_lose = streak_home.count("L")

        away_wins = streak_away.count("W")
        away_draws = streak_away.count("D")
        away_lose = streak_away.count("L")

        features =[home_wins, home_draws, home_lose,
                  away_wins, away_draws, away_lose]

        # Con factor temporal
        # features = []
        for match in streak_home:
            if match == "W":
                features.extend([1,0,0])
            elif match == "D":
                features.extend([0,1,0])
            elif match == "L":
                features.extend([0,0,1])

        for match in streak_away:
            if match == "W":
                features.extend([1,0,0])
            elif match == "D":
                features.extend([0,1,0])
            elif match == "L":
                features.extend([0,0,1])
                
        # Esta linea va solo si se agregan las caracteristicas promedio
        features.extend(resultados[i][4].tolist())
        features.extend(resultados[i][5].tolist())
        
        X.append(features)

        if result == "W":
            Y.append([1, 0, 0])
        elif result == "D":
            Y.append([0, 1, 0])
        elif result == "L":
            Y.append([0, 0, 1])

# %%
len(X[0])
# Out:
# 204

# %%
import random
from copy import deepcopy
# Pruebas con random, para ver si esta todo bien
copy_X = deepcopy(X)
random.shuffle(copy_X)
copy_Y = deepcopy(Y)
random.shuffle(copy_Y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 4
#       2 from copy import deepcopy
#       3 # Pruebas con random, para ver si esta todo bien
# ----> 4 copy_X = deepcopy(X)
#       5 random.shuffle(copy_X)
#       6 copy_Y = deepcopy(Y)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, index_train, index_test = train_test_split(
    X, Y, index, test_size=0.2)

drop = 0.0
model = model = models.Sequential()
model.add(layers.InputLayer(input_shape=(len(X[0]),)))
model.add(layers.Dense(32, activation='relu'),)
# model.add(layers.Dropout(drop))
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dropout(drop))
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dropout(drop))
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dropout(drop))
# model.add(layers.Dense(64, activation='relu'),)
# model.add(layers.Dense(64, activation='relu'),)
model.add(layers.Dense(3, activation='softmax'))
# # Compilamos el modelo
sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.1, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer="adam", metrics=['categorical_accuracy',])

# # Entrenamos el modelo
history = model.fit(X_train, y_train, verbose=1, epochs=100,
                    validation_data=(X_test, y_test))
print("hola")
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2266.3479 - categorical_accuracy: 0.3602 - val_loss: 724.5327 - val_categorical_accuracy: 0.3845
# Epoch 2/100
# 1875/1875 [==============================] - 2s 804us/step - loss: 1015.6255 - categorical_accuracy: 0.3670 - val_loss: 604.2666 - val_categorical_accuracy: 0.4427
# Epoch 3/100
# 1875/1875 [==============================] - 1s 798us/step - loss: 914.4570 - categorical_accuracy: 0.3733 - val_loss: 862.1494 - val_categorical_accuracy: 0.2761
# Epoch 4/100
# 1875/1875 [==============================] - 1s 795us/step - loss: 924.9063 - categorical_accuracy: 0.3719 - val_loss: 364.5779 - val_categorical_accuracy: 0.4132
# Epoch 5/100
# 1875/1875 [==============================] - 2s 813us/step - loss: 805.0296 - categorical_accuracy: 0.3772 - val_loss: 952.7382 - val_categorical_accuracy: 0.3789
# Epoch 6/100
# 1875/1875 [==============================] - 2s 808us/step - loss: 695.7596 - categorical_accuracy: 0.3773 - val_loss: 1207.7999 - val_categorical_accuracy: 0.4150
# Epoch 7/100
# 1875/1875 [==============================] - 2s 806us/step - loss: 687.6586 - categorical_accuracy: 0.3800 - val_loss: 311.0583 - val_categorical_accuracy: 0.3490
# Epoch 8/100
# 1875/1875 [==============================] - 1s 777us/step - loss: 638.0634 - categorical_accuracy: 0.3767 - val_loss: 482.6947 - val_categorical_accuracy: 0.3825
# Epoch 9/100
# 1875/1875 [==============================] - 1s 797us/step - loss: 569.6084 - categorical_accuracy: 0.3782 - val_loss: 267.1928 - val_categorical_accuracy: 0.4111
# Epoch 10/100
# 1875/1875 [==============================] - 2s 799us/step - loss: 496.5923 - categorical_accuracy: 0.3810 - val_loss: 394.9692 - val_categorical_accuracy: 0.3006
# Epoch 11/100
# 1875/1875 [==============================] - 1s 789us/step - loss: 486.2678 - categorical_accuracy: 0.3782 - val_loss: 366.0599 - val_categorical_accuracy: 0.3255
# Epoch 12/100
# 1875/1875 [==============================] - 2s 809us/step - loss: 405.9157 - categorical_accuracy: 0.3841 - val_loss: 451.0453 - val_categorical_accuracy: 0.4511
# Epoch 13/100
# 1875/1875 [==============================] - 1s 779us/step - loss: 375.7168 - categorical_accuracy: 0.3799 - val_loss: 262.4070 - val_categorical_accuracy: 0.4244
100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0723 - val_categorical_accuracy: 0.4393
# Epoch 37/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 38/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 39/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 40/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 41/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 42/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 43/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 44/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0724 - val_categorical_accuracy: 0.4393
# Epoch 45/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0730 - val_categorical_accuracy: 0.4393
# Epoch 46/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0727 - val_categorical_accuracy: 0.4393
# Epoch 47/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0724 - val_categorical_accuracy: 0.4393
# Epoch 48/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0710 - categorical_accuracy: 0.4435 - val_loss: 1.0723 - val_categorical_accuracy: 0.4393
# Epoch 49/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 50/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 51/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 52/100
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0724 - val_categorical_accuracy: 0.4393
# Epoch 53/100
# 1875/1875 [==============================] - 2s 876us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 54/100
# 1875/1875 [==============================] - 2s 863us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 55/100
# 1875/1875 [==============================] - 1s 796us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0724 - val_categorical_accuracy: 0.4393
# Epoch 56/100
# 1875/1875 [==============================] - 2s 829us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 57/100
# 1875/1875 [==============================] - 2s 861us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 58/100
# 1875/1875 [==============================] - 2s 843us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0726 - val_categorical_accuracy: 0.4393
# Epoch 59/100
# 1875/1875 [==============================] - 2s 850us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0728 - val_categorical_accuracy: 0.4393
# Epoch 60/100
# 1875/1875 [==============================] - 2s 915us/step - loss: 1.0711 - categorical_accuracy: 0.4435 - val_loss: 1.0725 - val_categorical_accuracy: 0.4393
# Epoch 61/100
# 1839/1875 [============================>.] - ETA: 0s - loss: 1.0712 - categorical_accuracy: 0.4432

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay
y_prob = model.predict(X_test)
y_test_metrics = np.argmax(y_test, axis=1)
y_pred = np.argmax(y_prob, axis=1)


# Matriz de confusión
conf_matrix = confusion_matrix(y_test_metrics, y_pred)
print('Matriz de Confusión:')
ConfusionMatrixDisplay(conf_matrix).plot()
plt.show()
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# 469/469 [==============================] - 0s 704us/step
# Matriz de Confusión:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %%
print(classification_report(y_test_metrics, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.93      0.61      6701
#            1       0.33      0.00      0.00      3812
#            2       0.41      0.11      0.18      4487
#
#     accuracy                           0.45     15000
#    macro avg       0.40      0.35      0.26     15000
# weighted avg       0.41      0.45      0.33     15000
