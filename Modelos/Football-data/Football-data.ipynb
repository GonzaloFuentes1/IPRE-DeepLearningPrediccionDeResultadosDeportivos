# %%
import soccerdata as sd
from joblib import Parallel, delayed
import pandas as pd
from tqdm import tqdm
# Out:
# [03/16/24 22:07:32] INFO     No custom team name replacements found. You can configure these in       ]8;id=433665;file://c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=888131;file://c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\gfuen\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=590063;file://c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=578284;file://c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\soccerdata\_config.py#177\177]8;;\
#                              C:\Users\gfuen\soccerdata\config\league_dict.json.

# %%
df = pd.read_csv("FootballData_ENG-Premier League.csv")

# %%
df
# Out:
#        Unnamed: 0.1 Div        Date   Time     HomeTeam     AwayTeam  FTHG  \
# 0               112  E0  01/01/1994    NaN  Aston Villa    Blackburn   0.0
# 1               113  E0  01/01/1994    NaN      Everton     West Ham   0.0
# 2               114  E0  01/01/1994    NaN      Ipswich    Liverpool   1.0
# 3               115  E0  01/01/1994    NaN   Man United        Leeds   0.0
# 4               116  E0  01/01/1994    NaN    Newcastle     Man City   2.0
# ...             ...  ..         ...    ...          ...          ...   ...
# 11747         11736  E0  31/12/2022  15:00     Man City      Everton   1.0
# 11748         11737  E0  31/12/2022  15:00    Newcastle        Leeds   0.0
# 11749         11738  E0  31/12/2022  17:30     Brighton      Arsenal   2.0
# 11750         11739  E0  31/12/2023  14:00       Fulham      Arsenal   2.0
# 11751         11740  E0  31/12/2023  14:00    Tottenham  Bournemouth   3.0
#
#        FTAG FTR  HTHG  ...  Attendance HHW AHW  HO  AO  HBP  ABP  SYH  SYD  \
# 0       1.0   A   NaN  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 1       1.0   A   NaN  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 2       2.0   A   NaN  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 3       0.0   D   NaN  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 4       0.0   H   NaN  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# ...     ...  ..   ...  ...         ...  ..  ..  ..  ..  ...  ...  ...  ...
# 11747   1.0   D   1.0  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 11748   0.0   D   0.0  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 11749   4.0   A   0.0  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 11750   1.0   H   1.0  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 11751   1.0   H   1.0  ...         NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
#
#        SYA
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 11747  NaN
# 11748  NaN
# 11749  NaN
# 11750  NaN
# 11751  NaN
#
# [11752 rows x 162 columns]
