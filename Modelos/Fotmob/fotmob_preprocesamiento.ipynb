# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import json
import os
import sys
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from random import choice
from time import time
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
df = pd.read_csv("datos_fotmob_completo.csv")
# Cambiamos los nombres de algunas variables, dropeamos los valores vacios y ordenamos por fecha
# La fecha va de la más antigua a la más nueva
df.rename(columns={'homeTeam_score': 'score_home',
          "awayTeam_score": "score_away"}, inplace=True)
df.rename(columns={'homeTeam': 'team_home',
          "awayTeam": "team_away"}, inplace=True)
df = df.sort_values(by="date", ignore_index=True)
df = df.drop(["discipline_away", "discipline_home", "duels_home", "duels_away",
             "defense_home", "defense_away", "shots_home", "shots_away"], axis=1)
df.head()
# Out:
#         id        date      leagueName          team_home        team_away  \
# 0  1474723  2014-01-01  Premier League       Swansea City  Manchester City
# 1  1475995  2014-01-01      League Two  Scunthorpe United         Rochdale
# 2  1474676  2014-01-01  Premier League            Arsenal     Cardiff City
# 3  1474680  2014-01-01  Premier League     Crystal Palace     Norwich City
# 4  1474689  2014-01-01  Premier League             Fulham  West Ham United
#
#    score_home  score_away  homeIdTeam  awayIdTeam  parentLeagueId  ...  \
# 0           2           3       10003        8456            47.0  ...
# 1           3           0        8412        8493           109.0  ...
# 2           2           0        9825        8344            47.0  ...
# 3           1           1        9826        9850            47.0  ...
# 4           2           1        9879        8654            47.0  ...
#
#    expected_goals_home  expected_goals_away  expected_goals_open_play_home  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3                  NaN                  NaN                            NaN
# 4                  NaN                  NaN                            NaN
#
#    expected_goals_open_play_away  expected_goals_set_play_home  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    expected_goals_set_play_away  expected_goals_non_penalty_home  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    expected_goals_non_penalty_away  expected_goals_on_target_home  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    expected_goals_on_target_away
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 85 columns]

# %%
columns_to_split = [
    "accurate_passes_home", "accurate_passes_away", 
    "long_balls_accurate_home", "long_balls_accurate_away", 
    "accurate_crosses_home", "accurate_crosses_away",
    "tackles_succeeded_home", "tackles_succeeded_away", 
    "ground_duels_won_home", "ground_duels_won_away", 
    "aerials_won_home", "aerials_won_away",
    "dribbles_succeeded_home", "dribbles_succeeded_away"
]
# Dividir y procesar cada columna
for column in columns_to_split:
    # Dividir la columna en dos columnas separadas
    df[[column+'_numerico', column+'_porcentaje']] = df[column].str.split(' ', expand=True)
    # Eliminar los paréntesis y el símbolo de porcentaje de la columna de porcentaje
    df[column+'_porcentaje'] = df[column+'_porcentaje'].str.replace('(', '').str.replace(')', '').str.replace('%', '')
    # Convertir las columnas en tipos de datos numéricos
    df[column+'_numerico'] = pd.to_numeric(df[column+'_numerico'])
    df[column+'_porcentaje'] = pd.to_numeric(df[column+'_porcentaje'])
# Eliminar las columnas originales que han sido divididas
df.drop(columns=columns_to_split, inplace=True)

# %%
def get_features(data):
    return pd.DataFrame(data[5:]).T


def search_features(i, df, last_games):
    team_home = df.iloc[i]["team_home"]
    team_away = df.iloc[i]["team_away"]
    # Para hacer la busqueda más eficiente, solo buscamos en los partidos que estos equipos juegan
    df_match_home1 = df[df["team_home"] == team_home]
    df_match_home2 = df[df["team_away"] == team_home]
    df_match_away1 = df[df["team_home"] == team_away]
    df_match_away2 = df[df["team_away"] == team_away]

    merged_df_home = pd.concat([df_match_home1, df_match_home2])
    merged_df_home.drop_duplicates(inplace=True)
    merged_df_home = merged_df_home.sort_values(by="date", ascending=False)

    merged_df_away = pd.concat([df_match_away1, df_match_away2])
    merged_df_away.drop_duplicates(inplace=True)
    merged_df_away = merged_df_away.sort_values(by="date", ascending=False)

    # El index 0 es el partido, por lo que iteramos desde el 1
    data_home = pd.DataFrame()
    data_away = pd.DataFrame()
    try:
        for j in range(1, last_games+1):
            if team_home == merged_df_home.iloc[j]["team_home"]:
                d = get_features(merged_df_home.iloc[j])
                d["played_home"] = 1
                d["played_away"] = 0
                data_home = pd.concat([data_home, d])
            elif team_home == merged_df_home.iloc[j]["team_away"]:
                d = get_features(merged_df_home.iloc[j])
                d["played_home"] = 0
                d["played_away"] = 1
                data_home = pd.concat([data_home, d])

        for j in range(1, last_games+1):
            if team_away == merged_df_away.iloc[j]["team_home"]:
                d = get_features(merged_df_away.iloc[j])
                d["played_home"] = 1
                d["played_away"] = 0

                data_away = pd.concat([data_away, d])
            elif team_away == merged_df_away .iloc[j]["team_away"]:
                d = get_features(merged_df_away.iloc[j])
                d["played_home"] = 0
                d["played_away"] = 1
                data_away = pd.concat([data_away, d])

        data = pd.concat([data_home, data_away])

        data = data.reset_index(drop=True)

        data = data.stack().to_frame().T

        #### Hiperparametro de max score
        maxs = 4
        # Resultado:
        # W = home_win, D = draw, L = home_lose
        if df.iloc[i]["score_home"] > df.iloc[i]["score_away"]:
            data["Resultado"] = "W"
        elif df.iloc[i]["score_home"] == df.iloc[i]["score_away"]:
            data["Resultado"] = "D"
        elif df.iloc[i]["score_home"] < df.iloc[i]["score_away"]:
            data["Resultado"] = "L"

        # Resultado númerico:
        home_score = df.iloc[i]["score_home"]
        away_score = df.iloc[i]["score_away"]
        # Buscar a cual le queda
        if home_score >= maxs and away_score < maxs:
            data["Resultado_Numerico"] = f"{maxs}>-{away_score}"
        elif home_score < maxs and away_score >= maxs:
            data["Resultado_Numerico"] = f"{home_score}-{maxs}>"
        elif home_score >= maxs and away_score >= maxs:
            data["Resultado_Numerico"] = f"{maxs}>-{maxs}>"
        else:
            data["Resultado_Numerico"] = f"{home_score}-{away_score}"

        df_f = pd.DataFrame()
        for i in range(2*last_games):
            parte = data[i].add_suffix(f"_{i}",axis=1)
            df_f = pd.concat([df_f,parte],axis=1)
            
        df_f["Resultado"] = np.array(data["Resultado"])
        df_f["Resultado_Numerico"] = np.array(data["Resultado_Numerico"])

        return df_f
    except:
        return pd.DataFrame()

# %%
# # Filtros de liga y equipo
# ID GUARDADOS :
# Premier Inglaterra : 47, LaLiga España : 87, Serie A Italiana : 55, Bundesliga Alemania : 54, Ligue1 Francia : 53
df_test = df
id = [47, 87, 55, 54, 53]
df_test = df.loc[df['parentLeagueId'].isin(id)]
# Pruebas de dataframe


df_test = df_test[df_test["red_cards_away"].notnull()].reset_index(drop=True)

# Primero solo quiero
df_test = df_test.drop(["parentLeagueId", "leagueId",
                       "homeIdTeam", "awayIdTeam"], axis=1)
df_test = df_test.drop(["touches_opp_box_home", "touches_opp_box_away", "expected_goals_home", "expected_goals_away",
                       "expected_goals_open_play_home", "expected_goals_open_play_away", "expected_goals_set_play_home",
                        "expected_goals_set_play_away", "expected_goals_non_penalty_home", "expected_goals_non_penalty_away",
                          "expected_goals_on_target_home","expected_goals_on_target_away"], axis=1)
df_test = df_test.dropna(axis=0)
columnas = list(df_test.columns)
# columnas

# %%
# Programa lineal
last_games = 15
resultados = []
df_nn = pd.DataFrame()
for i in tqdm(range(len(df_test))):
    info = search_features(i,df_test.head(i+1),last_games)
    resultados.append(info)
df_nn = pd.concat(resultados)
# Out:
#   0%|          | 0/92438 [00:00<?, ?it/s]
# 100%|██████████| 92438/92438 [1:43:25<00:00, 14.90it/s]

# %%
# Programa paralelo (Cuidado que a veces las particiones se quedan sin memoria, error de pickle)

# Last games = Juegos pasados a tener en cuenta
# Num_trabajadores = Trabajadores en paralelo (usar -1 para todos los posibles)
# Se demora un par de minutos
last_games = 15
num_trabajadores = -1
resultados = Parallel(n_jobs=num_trabajadores,verbose=10)(
    delayed(search_features)(i,df_test.head(i+1), last_games) for i in range(len(df_test)))
df_nn = pd.concat(resultados)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.18912055388544077s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.11426424980163574s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.11780953407287598s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 748 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 916 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 1084 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 1268 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 1452 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 1652 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 1852 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 2068 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 2284 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0054471821885396s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 2516 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 2678 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 2737 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 2768 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 2801 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 2834 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 2869 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 2904 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 2941 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1990274605121178s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 2978 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 3046 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 3124 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 3206 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 3288 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 3374 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 3460 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 3550 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 3640 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 3734 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 3828 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 3926 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 4024 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 4126 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 4228 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done 4334 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 4440 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done 4550 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done 4660 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=-1)]: Done 4774 tasks      | elapsed:   37.5s
# [Parallel(n_jobs=-1)]: Done 4888 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=-1)]: Done 5006 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 5124 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=-1)]: Done 5246 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done 5368 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 5494 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done 5620 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done 5750 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done 5880 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 6014 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done 6148 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 6286 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 6424 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=-1)]: Done 6566 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done 6708 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 6854 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 7000 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 7150 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 7300 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 7454 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 7608 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 7766 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 7924 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 8086 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 8248 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 8414 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 8580 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 8750 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 8920 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 9094 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 9268 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 9446 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 9624 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 9806 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 9988 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 10174 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 10360 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 10550 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 10740 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 10934 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 11128 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 11326 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 11524 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 11726 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 11928 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 12134 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 12340 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 12550 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 12760 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 12974 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 13188 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 13406 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 13624 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 13846 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 14068 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 14294 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 14520 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 14750 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 14980 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 15214 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 15448 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 15686 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 15924 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 16166 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 16408 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 16654 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 16900 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 17150 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 17400 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 17654 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 17908 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 18166 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 18424 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 18686 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 18948 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 19214 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 19480 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 19750 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 20020 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 20294 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 20568 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 20846 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 21124 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 21406 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 21688 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 21974 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 22260 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 22550 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 22840 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 23134 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 23428 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 23726 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 24024 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 24326 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 24628 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 24934 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 25240 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 25550 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 25860 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 26174 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 26488 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 26806 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 27124 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 27446 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 27768 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 28094 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 28420 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 28750 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0048146923849357s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 29080 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 29257 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 29424 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 29593 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 29762 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 29933 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 30104 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 30277 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 30450 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 30625 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 30800 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 30977 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 31154 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 31333 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 31512 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 31693 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 31874 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 32057 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 32240 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 32425 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 32610 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 32797 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 32984 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 33173 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 33362 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 33553 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 33744 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 33937 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 34130 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 34325 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 34520 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 34717 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 34914 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 35113 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 35312 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 35513 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 35714 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 35917 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 36120 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 36325 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 36530 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 36737 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 36944 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 37153 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 37362 tasks      | elapsed: 14.0min
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\queues.py", line 159, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\reduction.py", line 215, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\reduction.py", line 208, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\cloudpickle\cloudpickle_fast.py", line 632, in dump
#     return Pickler.dump(self, obj)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_memmapping_reducer.py", line 446, in __call__
#     for dumped_filename in dump(a, filename):
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\numpy_pickle.py", line 553, in dump
#     NumpyPickler(f, protocol=protocol).dump(value)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\pickle.py", line 487, in dump
#     self.save(obj)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\numpy_pickle.py", line 352, in save
#     wrapper.write_array(obj, self)
#   File "c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\numpy_pickle.py", line 134, in write_array
#     pickler.file_handle.write(chunk.tobytes('C'))
# OSError: [Errno 28] No space left on device
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# Cell In[39], line 8
#       6 last_games = 15
#       7 num_trabajadores = -1
# ----> 8 resultados = Parallel(n_jobs=num_trabajadores,verbose=10)(
#       9     delayed(search_features)(i,df_test.head(i+1), last_games) for i in range(len(df_test)))
#      10 df_nn = pd.concat(resultados)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File c:\Users\gfuen\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# PicklingError: Could not pickle the task to send it to the workers.

# %%
df_nn.head()
# Out:
#    MediaMovil_score_home_3  MediaMovil_score_home_6  MediaMovil_score_home_9  \
# 0                 0.000000                 0.500000                 4.000000
# 1                 0.333333                 0.000000                 0.333333
# 2                 0.000000                 0.333333                 0.111111
# 3                 0.666667                 0.500000                 0.000000
# 4                 0.000000                 2.000000                 0.000000
#
#    MediaMovil_score_home_12  MediaMovil_score_home_15  \
# 0                  2.000000                  0.133333
# 1                  4.000000                  2.000000
# 2                  1.000000                  0.000000
# 3                  0.000000                  0.133333
# 4                  0.083333                  4.000000
#
#    MediaMovil_BallPossesion_home_3  MediaMovil_BallPossesion_home_6  \
# 0                        54.000000                         8.666667
# 1                        17.666667                        54.000000
# 2                        45.000000                         8.000000
# 3                        14.333333                         6.666667
# 4                        19.000000                        55.000000
#
#    MediaMovil_BallPossesion_home_9  MediaMovil_BallPossesion_home_12  \
# 0                        72.000000                             58.00
# 1                         5.777778                             72.00
# 2                         5.555556                             47.00
# 3                         6.111111                              3.50
# 4                        65.000000                              5.25
#
#    MediaMovil_BallPossesion_home_15  ...  \
# 0                          3.733333  ...
# 1                         58.000000  ...
# 2                          2.333333  ...
# 3                          2.333333  ...
# 4                         61.000000  ...
#
#    MediaMovil_dribbles_succeeded_home_numerico_9  \
# 0                                      12.000000
# 1                                       1.222222
# 2                                       1.333333
# 3                                       2.111111
# 4                                      16.000000
#
#    MediaMovil_dribbles_succeeded_home_numerico_12  \
# 0                                       11.000000
# 1                                       12.000000
# 2                                        6.000000
# 3                                        0.583333
# 4                                        0.666667
#
#    MediaMovil_dribbles_succeeded_home_numerico_15  \
# 0                                        0.466667
# 1                                       11.000000
# 2                                        0.733333
# 3                                        0.533333
# 4                                        8.000000
#
#    MediaMovil_dribbles_succeeded_home_porcentaje_3  \
# 0                                        48.000000
# 1                                        18.666667
# 2                                        52.000000
# 3                                        14.000000
# 4                                        16.000000
#
#    MediaMovil_dribbles_succeeded_home_porcentaje_6  \
# 0                                         9.666667
# 1                                        48.000000
# 2                                         6.000000
# 3                                         8.333333
# 4                                        60.000000
#
#    MediaMovil_dribbles_succeeded_home_porcentaje_9  \
# 0                                        55.000000
# 1                                         6.444444
# 2                                         6.333333
# 3                                         7.000000
# 4                                        76.000000
#
#    MediaMovil_dribbles_succeeded_home_porcentaje_12  \
# 0                                              39.0
# 1                                              55.0
# 2                                              75.0
# 3                                               4.5
# 4                                               3.5
#
#    MediaMovil_dribbles_succeeded_home_porcentaje_15  Resultado  \
# 0                                          2.733333          D
# 1                                         39.000000          L
# 2                                          4.600000          L
# 3                                          3.533333          L
# 4                                         53.000000          W
#
#    Resultado_Numerico
# 0                 1-1
# 1                0-4>
# 2                 1-3
# 3                 2-3
# 4                 3-2
#
# [5 rows x 197 columns]

# %%
df_nn.to_csv("Dataframe_Auxiliar.csv")

# %%
df = pd.read_csv("Dataframe_Auxiliar.csv")
df = df.drop("Unnamed: 0", axis=1 )

# %%
df
# Out:
#        score_home_0  score_away_0  BallPossesion_home_0  BallPossesion_away_0  \
# 0                 1             2                  49.0                  51.0
# 1                 2             2                  60.0                  40.0
# 2                 1             1                  53.0                  47.0
# 3                 1             1                  74.0                  26.0
# 4                 2             3                  56.0                  44.0
# ...             ...           ...                   ...                   ...
# 75014             3             0                  39.0                  61.0
# 75015             1             2                  57.0                  43.0
# 75016             2             1                  56.0                  44.0
# 75017             1             1                  53.0                  47.0
# 75018             0             0                  61.0                  39.0
#
#        ShotsOnTarget_home_0  ShotsOnTarget_away_0  ShotsOffTarget_home_0  \
# 0                       7.0                   5.0                   10.0
# 1                       7.0                   5.0                   12.0
# 2                       5.0                   4.0                    6.0
# 3                       2.0                   3.0                    9.0
# 4                       6.0                   2.0                    9.0
# ...                     ...                   ...                    ...
# 75014                   8.0                   3.0                    4.0
# 75015                   3.0                   7.0                    4.0
# 75016                   5.0                   3.0                    4.0
# 75017                   4.0                   3.0                    4.0
# 75018                   3.0                   0.0                    5.0
#
#        ShotsOffTarget_away_0  fouls_home_0  fouls_away_0  ...  \
# 0                        5.0           8.0          15.0  ...
# 1                        2.0          16.0          20.0  ...
# 2                        7.0          10.0          22.0  ...
# 3                        6.0           8.0          18.0  ...
# 4                        2.0           6.0          14.0  ...
# ...                      ...           ...           ...  ...
# 75014                    8.0          10.0          17.0  ...
# 75015                    7.0           9.0          15.0  ...
# 75016                    5.0          18.0          14.0  ...
# 75017                    2.0          13.0          17.0  ...
# 75018                    7.0          18.0           7.0  ...
#
#        aerials_won_away_numerico_29  aerials_won_away_porcentaje_29  \
# 0                              23.0                            59.0
# 1                              13.0                            76.0
# 2                              16.0                            52.0
# 3                              12.0                            40.0
# 4                              19.0                            61.0
# ...                             ...                             ...
# 75014                          21.0                            48.0
# 75015                           5.0                            29.0
# 75016                          31.0                            50.0
# 75017                          16.0                            47.0
# 75018                          15.0                            47.0
#
#        dribbles_succeeded_home_numerico_29  \
# 0                                     10.0
# 1                                      7.0
# 2                                      7.0
# 3                                      6.0
# 4                                      2.0
# ...                                    ...
# 75014                                  2.0
# 75015                                  9.0
# 75016                                  7.0
# 75017                                  9.0
# 75018                                  5.0
#
#        dribbles_succeeded_home_porcentaje_29  \
# 0                                       50.0
# 1                                       41.0
# 2                                       39.0
# 3                                       60.0
# 4                                       33.0
# ...                                      ...
# 75014                                   29.0
# 75015                                   50.0
# 75016                                   70.0
# 75017                                   53.0
# 75018                                   50.0
#
#        dribbles_succeeded_away_numerico_29  \
# 0                                     13.0
# 1                                     13.0
# 2                                      3.0
# 3                                      8.0
# 4                                      8.0
# ...                                    ...
# 75014                                  3.0
# 75015                                  1.0
# 75016                                  8.0
# 75017                                  4.0
# 75018                                  5.0
#
#        dribbles_succeeded_away_porcentaje_29  played_home_29  played_away_29  \
# 0                                       76.0               1               0
# 1                                       65.0               0               1
# 2                                       43.0               1               0
# 3                                       62.0               0               1
# 4                                       50.0               0               1
# ...                                      ...             ...             ...
# 75014                                   38.0               1               0
# 75015                                   13.0               0               1
# 75016                                   50.0               1               0
# 75017                                   80.0               0               1
# 75018                                   56.0               1               0
#
#        Resultado  Resultado_Numerico
# 0              D                 1-1
# 1              L                0-4>
# 2              L                 1-3
# 3              L                 2-3
# 4              W                 3-2
# ...          ...                 ...
# 75014          L                 0-1
# 75015          W                 2-0
# 75016          W                 3-1
# 75017          D                 3-3
# 75018          D                 0-0
#
# [75019 rows x 2402 columns]

# %%
last_games = 15


# Función para filtrar strings que contienen "home"
def contiene_home(string):
  return "home" in string.lower()

# Obtener strings que contienen "home"
features = list(filter(contiene_home, columnas))


# Medias_moviles, ARREGLAR NO TOMA SI ES VISITA O HOME
df_nn = pd.DataFrame()
for fea in features[1:]:
    for i in [5,10,15]:
        suma = 0
        for j in range(i):
          try:
            fea_away = fea.replace("home", "away")
            fea_not_home = fea.replace("home", "")
            df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
            df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i

            df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
            df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
            
          except:
            print(fea)

df_nn["Resultado"] = np.array(df["Resultado"])
df_nn["Resultado_Numerico"] = np.array(df["Resultado_Numerico"])
# Out:
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn["Resultado"] = np.array(df["Resultado"])
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_13040\49544224.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn["Resultado_Numerico"] = np.array(df["Resultado_Numerico"])

# %%
df_nn.to_csv("Media_Movil_5.csv")
