# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import json
import os
import sys
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from random import choice
from time import time
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
df = pd.read_csv("datos_fotmob_completo.csv")
# Cambiamos los nombres de algunas variables, dropeamos los valores vacios y ordenamos por fecha
# La fecha va de la más antigua a la más nueva
df.rename(columns={'homeTeam_score': 'score_home',
          "awayTeam_score": "score_away"}, inplace=True)
df.rename(columns={'homeTeam': 'team_home',
          "awayTeam": "team_away"}, inplace=True)
df = df.sort_values(by="date", ignore_index=True)
df = df.drop(["discipline_away", "discipline_home", "duels_home", "duels_away",
             "defense_home", "defense_away", "shots_home", "shots_away"], axis=1)
df.head()
# Out:
#         id        date      leagueName          team_home        team_away  \
# 0  1474723  2014-01-01  Premier League       Swansea City  Manchester City
# 1  1475995  2014-01-01      League Two  Scunthorpe United         Rochdale
# 2  1474676  2014-01-01  Premier League            Arsenal     Cardiff City
# 3  1474680  2014-01-01  Premier League     Crystal Palace     Norwich City
# 4  1474689  2014-01-01  Premier League             Fulham  West Ham United
#
#    score_home  score_away  homeIdTeam  awayIdTeam  parentLeagueId  ...  \
# 0           2           3       10003        8456            47.0  ...
# 1           3           0        8412        8493           109.0  ...
# 2           2           0        9825        8344            47.0  ...
# 3           1           1        9826        9850            47.0  ...
# 4           2           1        9879        8654            47.0  ...
#
#    expected_goals_home  expected_goals_away  expected_goals_open_play_home  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3                  NaN                  NaN                            NaN
# 4                  NaN                  NaN                            NaN
#
#    expected_goals_open_play_away  expected_goals_set_play_home  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    expected_goals_set_play_away  expected_goals_non_penalty_home  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    expected_goals_non_penalty_away  expected_goals_on_target_home  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    expected_goals_on_target_away
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 85 columns]

# %%
columns_to_split = [
    "accurate_passes_home", "accurate_passes_away", 
    "long_balls_accurate_home", "long_balls_accurate_away", 
    "accurate_crosses_home", "accurate_crosses_away",
    "tackles_succeeded_home", "tackles_succeeded_away", 
    "ground_duels_won_home", "ground_duels_won_away", 
    "aerials_won_home", "aerials_won_away",
    "dribbles_succeeded_home", "dribbles_succeeded_away"
]
# Dividir y procesar cada columna
for column in columns_to_split:
    # Dividir la columna en dos columnas separadas
    df[[column+'_numerico', column+'_porcentaje']] = df[column].str.split(' ', expand=True)
    # Eliminar los paréntesis y el símbolo de porcentaje de la columna de porcentaje
    df[column+'_porcentaje'] = df[column+'_porcentaje'].str.replace('(', '').str.replace(')', '').str.replace('%', '')
    # Convertir las columnas en tipos de datos numéricos
    df[column+'_numerico'] = pd.to_numeric(df[column+'_numerico'])
    df[column+'_porcentaje'] = pd.to_numeric(df[column+'_porcentaje'])
# Eliminar las columnas originales que han sido divididas
df.drop(columns=columns_to_split, inplace=True)

# %%
def get_features(data):
    return pd.DataFrame(data[5:]).T


def search_features(i, df, last_games):
    team_home = df.iloc[i]["team_home"]
    team_away = df.iloc[i]["team_away"]
    # Para hacer la busqueda más eficiente, solo buscamos en los partidos que estos equipos juegan
    df_match_home1 = df[df["team_home"] == team_home]
    df_match_home2 = df[df["team_away"] == team_home]
    df_match_away1 = df[df["team_home"] == team_away]
    df_match_away2 = df[df["team_away"] == team_away]

    merged_df_home = pd.concat([df_match_home1, df_match_home2])
    merged_df_home.drop_duplicates(inplace=True)
    merged_df_home = merged_df_home.sort_values(by="date", ascending=False)

    merged_df_away = pd.concat([df_match_away1, df_match_away2])
    merged_df_away.drop_duplicates(inplace=True)
    merged_df_away = merged_df_away.sort_values(by="date", ascending=False)

    # El index 0 es el partido, por lo que iteramos desde el 1
    data_home = pd.DataFrame()
    data_away = pd.DataFrame()
    try:
        for j in range(1, last_games+1):
            if team_home == merged_df_home.iloc[j]["team_home"]:
                d = get_features(merged_df_home.iloc[j])
                d["played_home"] = 1
                d["played_away"] = 0
                data_home = pd.concat([data_home, d])
            elif team_home == merged_df_home.iloc[j]["team_away"]:
                d = get_features(merged_df_home.iloc[j])
                d["played_home"] = 0
                d["played_away"] = 1
                data_home = pd.concat([data_home, d])

        for j in range(1, last_games+1):
            if team_away == merged_df_away.iloc[j]["team_home"]:
                d = get_features(merged_df_away.iloc[j])
                d["played_home"] = 1
                d["played_away"] = 0

                data_away = pd.concat([data_away, d])
            elif team_away == merged_df_away .iloc[j]["team_away"]:
                d = get_features(merged_df_away.iloc[j])
                d["played_home"] = 0
                d["played_away"] = 1
                data_away = pd.concat([data_away, d])

        data = pd.concat([data_home, data_away])

        data = data.reset_index(drop=True)

        data = data.stack().to_frame().T

        #### Hiperparametro de max score
        maxs = 4
        # Resultado:
        # W = home_win, D = draw, L = home_lose
        if df.iloc[i]["score_home"] > df.iloc[i]["score_away"]:
            data["Resultado"] = "W"
        elif df.iloc[i]["score_home"] == df.iloc[i]["score_away"]:
            data["Resultado"] = "D"
        elif df.iloc[i]["score_home"] < df.iloc[i]["score_away"]:
            data["Resultado"] = "L"

        # Resultado númerico:
        home_score = df.iloc[i]["score_home"]
        away_score = df.iloc[i]["score_away"]
        # Buscar a cual le queda
        if home_score >= maxs and away_score < maxs:
            data["Resultado_Numerico"] = f"{maxs}>-{away_score}"
        elif home_score < maxs and away_score >= maxs:
            data["Resultado_Numerico"] = f"{home_score}-{maxs}>"
        elif home_score >= maxs and away_score >= maxs:
            data["Resultado_Numerico"] = f"{maxs}>-{maxs}>"
        else:
            data["Resultado_Numerico"] = f"{home_score}-{away_score}"

        df_f = pd.DataFrame()
        for i in range(2*last_games):
            parte = data[i].add_suffix(f"_{i}",axis=1)
            df_f = pd.concat([df_f,parte],axis=1)
            
        df_f["Resultado"] = np.array(data["Resultado"])
        df_f["Resultado_Numerico"] = np.array(data["Resultado_Numerico"])

        return df_f
    except:
        return pd.DataFrame()

# %%
# # Filtros de liga y equipo
# ID GUARDADOS :
# Premier Inglaterra : 47, LaLiga España : 87, Serie A Italiana : 55, Bundesliga Alemania : 54, Ligue1 Francia : 53
df_test = df
id = [47, 87, 55, 54, 53]
df_test = df.loc[df['parentLeagueId'].isin(id)]
# Pruebas de dataframe


df_test = df_test[df_test["red_cards_away"].notnull()].reset_index(drop=True)

# Primero solo quiero
df_test = df_test.drop(["parentLeagueId", "leagueId",
                       "homeIdTeam", "awayIdTeam"], axis=1)
df_test = df_test.drop(["touches_opp_box_home", "touches_opp_box_away", "expected_goals_home", "expected_goals_away",
                       "expected_goals_open_play_home", "expected_goals_open_play_away", "expected_goals_set_play_home",
                        "expected_goals_set_play_away", "expected_goals_non_penalty_home", "expected_goals_non_penalty_away",
                          "expected_goals_on_target_home","expected_goals_on_target_away"], axis=1)
df_test = df_test.dropna(axis=0)
columnas = list(df_test.columns)
# columnas

# %%
# Programa lineal
last_games = 15
resultados = []
df_nn = pd.DataFrame()
for i in tqdm(range(len(df_test))):
    info = search_features(i,df_test.head(i+1),last_games)
    resultados.append(info)
df_nn = pd.concat(resultados)
# Out:
#   0%|          | 0/92438 [00:00<?, ?it/s]
# 100%|██████████| 92438/92438 [1:43:25<00:00, 14.90it/s]

# %%
# Programa paralelo (Cuidado que a veces las particiones se quedan sin memoria, error de pickle)

# Last games = Juegos pasados a tener en cuenta
# Num_trabajadores = Trabajadores en paralelo (usar -1 para todos los posibles)
# Se demora un par de minutos
last_games = 15
num_trabajadores = -1
resultados = Parallel(n_jobs=num_trabajadores,verbose=10)(
    delayed(search_features)(i,df_test.head(i+1), last_games) for i in range(len(df_test)))
df_nn = pd.concat(resultados)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19696119375409696s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.12178421020507812s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.11834526062011719s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 748 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 916 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 1084 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 1268 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 1452 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 1652 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 1852 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 2068 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 2284 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 2516 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 2748 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0093623727073178s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 2996 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 3160 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 3221 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done 3254 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 3289 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done 3324 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 3361 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 3398 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 3437 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 3476 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 3517 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 3558 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 3601 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 3644 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 3689 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 3734 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 3781 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done 3828 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 3877 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done 3926 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 3977 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done 4028 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 4081 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 4134 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 4189 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done 4244 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done 4301 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done 4358 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done 4417 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done 4476 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=-1)]: Done 4537 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=-1)]: Done 4598 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=-1)]: Done 4661 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done 4724 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done 4789 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 4854 tasks      | elapsed:   43.9s
# [Parallel(n_jobs=-1)]: Done 4921 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=-1)]: Done 4988 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done 5057 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=-1)]: Done 5126 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 5197 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done 5268 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 5341 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 5414 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 5489 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=-1)]: Done 5564 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 5641 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 5718 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=-1)]: Done 5797 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done 5876 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 5957 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done 6038 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 6121 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 6204 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 6289 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 6374 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 6461 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 6548 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 6637 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 6726 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 6817 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 6908 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 7001 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 7094 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 7189 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 7284 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 7381 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 7478 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 7577 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 7676 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 7777 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 7878 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 7981 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 8084 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 8189 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 8294 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 8401 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 8508 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 8617 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 8726 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 8837 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 8948 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 9061 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 9174 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 9289 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 9404 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 9521 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 9638 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 9757 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 9876 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 9997 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 10118 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 10241 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 10364 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 10489 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 10614 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 10741 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 10868 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 10997 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 11126 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 11257 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 11388 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 11521 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 11654 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 11789 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 11924 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 12061 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 12198 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 12337 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 12476 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 12617 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 12758 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 12901 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 13044 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 13189 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 13334 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 13481 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 13628 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 13653 out of 13653 | elapsed:  3.2min finished

# %%
df_nn.head()
# Out:
#   score_home_0 score_away_0 BallPossesion_home_0 BallPossesion_away_0  \
# 0            2            1                 36.0                 64.0
# 0            1            2                 41.0                 59.0
# 0            0            0                 65.0                 35.0
# 0            1            1                 73.0                 27.0
# 0            3            0                 55.0                 45.0
#
#   ShotsOnTarget_home_0 ShotsOnTarget_away_0 ShotsOffTarget_home_0  \
# 0                  4.0                  3.0                   8.0
# 0                  3.0                  6.0                   4.0
# 0                  3.0                  1.0                   3.0
# 0                  8.0                  2.0                   5.0
# 0                  6.0                  0.0                   6.0
#
#   ShotsOffTarget_away_0 fouls_home_0 fouls_away_0  ...  \
# 0                   2.0          9.0         15.0  ...
# 0                   3.0         11.0          9.0  ...
# 0                   5.0         14.0         20.0  ...
# 0                   1.0          7.0          9.0  ...
# 0                   3.0          6.0         12.0  ...
#
#   aerials_won_away_numerico_29 aerials_won_away_porcentaje_29  \
# 0                         18.0                           44.0
# 0                         11.0                           42.0
# 0                          9.0                           43.0
# 0                         27.0                           61.0
# 0                         33.0                           65.0
#
#   dribbles_succeeded_home_numerico_29 dribbles_succeeded_home_porcentaje_29  \
# 0                                 9.0                                  47.0
# 0                                13.0                                  57.0
# 0                                14.0                                  64.0
# 0                                10.0                                  59.0
# 0                                 7.0                                  39.0
#
#   dribbles_succeeded_away_numerico_29 dribbles_succeeded_away_porcentaje_29  \
# 0                                12.0                                  63.0
# 0                                12.0                                  48.0
# 0                                 9.0                                  60.0
# 0                                10.0                                  48.0
# 0                                 6.0                                  60.0
#
#   played_home_29 played_away_29 Resultado Resultado_Numerico
# 0              0              1         W                2-0
# 0              0              1         D                0-0
# 0              0              1         W                2-1
# 0              0              1         D                1-1
# 0              1              0         W               4>-0
#
# [5 rows x 2402 columns]

# %%
df_nn.to_csv("Dataframe_Auxiliar.csv")

# %%
df = pd.read_csv("Dataframe_Auxiliar.csv")
df = df.drop("Unnamed: 0", axis=1 )

# %%
df
# Out:
#        score_home_0  score_away_0  BallPossesion_home_0  BallPossesion_away_0  \
# 0                 2             1                  36.0                  64.0
# 1                 1             2                  41.0                  59.0
# 2                 0             0                  65.0                  35.0
# 3                 1             1                  73.0                  27.0
# 4                 3             0                  55.0                  45.0
# ...             ...           ...                   ...                   ...
# 11896             3             2                  46.0                  54.0
# 11897             1             3                  62.0                  38.0
# 11898             2             1                  64.0                  36.0
# 11899             4             2                  45.0                  55.0
# 11900             3             0                  42.0                  58.0
#
#        ShotsOnTarget_home_0  ShotsOnTarget_away_0  ShotsOffTarget_home_0  \
# 0                       4.0                   3.0                    8.0
# 1                       3.0                   6.0                    4.0
# 2                       3.0                   1.0                    3.0
# 3                       8.0                   2.0                    5.0
# 4                       6.0                   0.0                    6.0
# ...                     ...                   ...                    ...
# 11896                   7.0                   4.0                    3.0
# 11897                   7.0                   6.0                    6.0
# 11898                   4.0                   5.0                    3.0
# 11899                   9.0                   3.0                    3.0
# 11900                   4.0                   3.0                    4.0
#
#        ShotsOffTarget_away_0  fouls_home_0  fouls_away_0  ...  \
# 0                        2.0           9.0          15.0  ...
# 1                        3.0          11.0           9.0  ...
# 2                        5.0          14.0          20.0  ...
# 3                        1.0           7.0           9.0  ...
# 4                        3.0           6.0          12.0  ...
# ...                      ...           ...           ...  ...
# 11896                    2.0          10.0          10.0  ...
# 11897                    6.0          10.0          11.0  ...
# 11898                    3.0          13.0          16.0  ...
# 11899                    8.0          18.0           6.0  ...
# 11900                    1.0          10.0          10.0  ...
#
#        aerials_won_away_numerico_29  aerials_won_away_porcentaje_29  \
# 0                              18.0                            44.0
# 1                              11.0                            42.0
# 2                               9.0                            43.0
# 3                              27.0                            61.0
# 4                              33.0                            65.0
# ...                             ...                             ...
# 11896                          11.0                            48.0
# 11897                           5.0                            83.0
# 11898                          15.0                            39.0
# 11899                          15.0                            39.0
# 11900                           9.0                            47.0
#
#        dribbles_succeeded_home_numerico_29  \
# 0                                      9.0
# 1                                     13.0
# 2                                     14.0
# 3                                     10.0
# 4                                      7.0
# ...                                    ...
# 11896                                 10.0
# 11897                                 22.0
# 11898                                  4.0
# 11899                                  4.0
# 11900                                  3.0
#
#        dribbles_succeeded_home_porcentaje_29  \
# 0                                       47.0
# 1                                       57.0
# 2                                       64.0
# 3                                       59.0
# 4                                       39.0
# ...                                      ...
# 11896                                   53.0
# 11897                                   71.0
# 11898                                   22.0
# 11899                                   22.0
# 11900                                   43.0
#
#        dribbles_succeeded_away_numerico_29  \
# 0                                     12.0
# 1                                     12.0
# 2                                      9.0
# 3                                     10.0
# 4                                      6.0
# ...                                    ...
# 11896                                  2.0
# 11897                                  6.0
# 11898                                  8.0
# 11899                                  8.0
# 11900                                 10.0
#
#        dribbles_succeeded_away_porcentaje_29  played_home_29  played_away_29  \
# 0                                       63.0               0               1
# 1                                       48.0               0               1
# 2                                       60.0               0               1
# 3                                       48.0               0               1
# 4                                       60.0               1               0
# ...                                      ...             ...             ...
# 11896                                   22.0               1               0
# 11897                                   38.0               1               0
# 11898                                   38.0               1               0
# 11899                                   38.0               0               1
# 11900                                   59.0               0               1
#
#        Resultado  Resultado_Numerico
# 0              W                 2-0
# 1              D                 0-0
# 2              W                 2-1
# 3              D                 1-1
# 4              W                4>-0
# ...          ...                 ...
# 11896          W                 3-2
# 11897          W                 2-1
# 11898          W                 3-1
# 11899          W                 3-1
# 11900          W                 2-1
#
# [11901 rows x 2402 columns]

# %%
last_games = 15


# Función para filtrar strings que contienen "home"
def contiene_home(string):
  return "home" in string.lower()

# Obtener strings que contienen "home"
features = list(filter(contiene_home, columnas))


# Medias_moviles, ARREGLAR NO TOMA SI ES VISITA O HOME
df_nn = pd.DataFrame()
for fea in features[1:]:
    for i in [5,10,15]:
        suma = 0
        for j in range(i):
          try:
            fea_away = fea.replace("home", "away")
            fea_not_home = fea.replace("home", "")
            df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
            df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i

            df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
            df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
            
          except:
            print(fea)

df_nn["Resultado"] = np.array(df["Resultado"])
df_nn["Resultado_Numerico"] = np.array(df["Resultado_Numerico"])
# Out:
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_1"] = (df[f"{fea_away}_{j}"]*df[f"played_away_{j}"] + df[f"{fea}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_h_2"] = (df[f"{fea_away}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_1"] = (df[f"{fea}_{j}"]*df[f"played_away_{j}"] + df[f"{fea_away}_{j}"]*df[f"played_home_{j}"])/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn[f"MediaMovil_{i}_{fea_not_home}_a_2"] = (df[f"{fea}_{j}"]*(1-df[f"played_away_{j}"]) + df[f"{fea_away}_{j}"]*(1-df[f"played_home_{j}"]))/i
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn["Resultado"] = np.array(df["Resultado"])
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_16500\49544224.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_nn["Resultado_Numerico"] = np.array(df["Resultado_Numerico"])

# %%
df_nn.to_csv("Media_Movil_5.csv")

# %%
features
# Out:
# ['team_home',
#  'score_home',
#  'BallPossesion_home',
#  'ShotsOnTarget_home',
#  'ShotsOffTarget_home',
#  'fouls_home',
#  'Offsides_home',
#  'corners_home',
#  'total_shots_home',
#  'big_chance_home',
#  'big_chance_missed_title_home',
#  'blocked_shots_home',
#  'shots_woodwork_home',
#  'shots_inside_box_home',
#  'shots_outside_box_home',
#  'passes_home',
#  'own_half_passes_home',
#  'opposition_half_passes_home',
#  'player_throws_home',
#  'interceptions_home',
#  'shot_blocks_home',
#  'clearances_home',
#  'keeper_saves_home',
#  'duel_won_home',
#  'yellow_cards_home',
#  'red_cards_home',
#  'accurate_passes_home_numerico',
#  'accurate_passes_home_porcentaje',
#  'long_balls_accurate_home_numerico',
#  'long_balls_accurate_home_porcentaje',
#  'accurate_crosses_home_numerico',
#  'accurate_crosses_home_porcentaje',
#  'tackles_succeeded_home_numerico',
#  'tackles_succeeded_home_porcentaje',
#  'ground_duels_won_home_numerico',
#  'ground_duels_won_home_porcentaje',
#  'aerials_won_home_numerico',
#  'aerials_won_home_porcentaje',
#  'dribbles_succeeded_home_numerico',
#  'dribbles_succeeded_home_porcentaje']
