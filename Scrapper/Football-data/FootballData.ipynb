# %%
import pandas as pd

# %%
df = pd.read_csv("T1.csv")
for i in range(1,30):
    df_concat = pd.read_csv(f"T1 ({i}).csv", encoding='unicode_escape', on_bad_lines='skip')
    df = pd.concat([df, df_concat],ignore_index=True)
df = df.drop_duplicates()
df = df.filter(regex='^(?!Unnamed)').reset_index(drop=True)
df
# Out:
#      Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     T1  11/08/2023  19:00  Trabzonspor    Antalyaspor   1.0   0.0   H   1.0
# 1     T1  12/08/2023  17:15    Kasimpasa     Ankaragucu   3.0   2.0   H   1.0
# 2     T1  12/08/2023  17:15    Konyaspor   Istanbulspor   1.0   1.0   D   0.0
# 3     T1  12/08/2023  19:45  Kayserispor    Galatasaray   0.0   0.0   D   0.0
# 4     T1  12/08/2023  19:45   Pendikspor      Hatayspor   1.0   5.0   A   0.0
# ...   ..         ...    ...          ...            ...   ...   ...  ..   ...
# 9158  T1    21/05/95    NaN   Fenerbahce  Gaziantepspor   2.0   0.0   H   NaN
# 9159  T1    21/05/95    NaN  Kocaelispor        Kayseri   4.0   3.0   H   NaN
# 9160  T1    21/05/95    NaN  Trabzonspor       P. Ofisi   3.0   2.0   H   NaN
# 9161  T1    21/05/95    NaN      Vanspor        Antalya   1.0   4.0   A   NaN
# 9162  T1    21/05/95    NaN  Zeytinburnu    Galatasaray   3.0   7.0   A   NaN
#
# ...

# %%
df.to_csv("FootballData_TUR-SuperLig.csv")

# %% [markdown]
# ## Para ordenarlos

# %%
leagues = ['ARG-PrimeraDivision', 'BRA-Brasileirao','ENG-Premier League', 'ESP-La Liga', 'FRA-Ligue 1',
           'GER-Bundesliga', 'ITA-Serie A', 'NED-Eredivisie', 'POR-PrimeiraDivisao', 'RUS-PremierLeague', 'SCO-Premiership', 'TUR-SuperLig', 'USA-MLS']
# Chat GPT
def fix_date_format(date_str):
    # Divide la cadena de fecha en día, mes y año
    parts = date_str.split('/')
    
    # Formatea el año a cuatro dígitos si es necesario
    year = parts[-1]
    if len(year) == 2:
        if int(year) > 50:
            year = f"19{year}"
        else:
            year = f"20{year}"
    
    # Formatea la fecha como XX/XX/XXXX
    formatted_date = f"{parts[0]}/{parts[1]}/{year}"
    return formatted_date

for l in leagues:
    df = pd.read_csv(f"FootballData_{l}.csv").dropna(subset=["Date"])
    df['Date'] = df['Date'].apply(fix_date_format)
    df = df.sort_values(by=["Date","Time"],ignore_index=True)
    df.to_csv(f"FootballData_{l}.csv",index=False)
# Out:
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_25188\2975411832.py:21: DtypeWarning: Columns (1,2,3,4,5,8,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"FootballData_{l}.csv").dropna(subset=["Date"])
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_25188\2975411832.py:21: DtypeWarning: Columns (65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"FootballData_{l}.csv").dropna(subset=["Date"])
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_25188\2975411832.py:21: DtypeWarning: Columns (119) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"FootballData_{l}.csv").dropna(subset=["Date"])
# C:\Users\gfuen\AppData\Local\Temp\ipykernel_25188\2975411832.py:21: DtypeWarning: Columns (74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"FootballData_{l}.csv").dropna(subset=["Date"])
